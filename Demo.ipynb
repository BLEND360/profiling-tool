# %%
# https://github.com/BLEND360/profiling-tool

# %% [markdown]
# After extracting the files open anaconda prompt and go to profiling-tool-main directory and use below code to install all requirements

# %%
# python -m pip install -e profiling-tool-main

# %% [markdown]
# Before starting, complete these mandatory steps:
# <ul>
#     <li>Open an excel file.</li>
#     <li>Open ‘File’ then select ‘Options’.</li>
#     <li>In the Excel Options pop up select ‘Trust Center’ then ‘Trust Center Settings’.</li>
#     <li>Then select ‘Macro Settings’</li>
#     <li>In Macro Settings select ‘Enable VBA macros’ and check boxes ‘Enable Excel 4.0 macros when VBA macros are enabled’ and ‘Trust access to the VBA project object model’.</li>
# </ul>

# %% [markdown]
# ## Import Package

# %%
from edap import ExcelReport

# %% [markdown]
# ## Generate Summary Sheet

# %% [markdown]
# Class which contains all the function required
#
# :param null_percentage_to_drop_column: Drop the columns which have null percentage above this value <bR>
# :param depedant_target_variable: Target variable

# %%
excel_report = ExcelReport('df_input.csv', null_percentage_to_drop_column=90, dependant_target_variable='Target')

# %% [markdown]
# Generates a summary of the given dataset
#
# :return: excel file which contains the summary of the given dataset

# %%
# generates an excel file with a summary of all the variables
excel_report.generate_report()

# %% [markdown]
# You can generate the summary sheet or not on your preference. <br><br>
# <b>If generated </b><br>
# You can treat missing values, outlier and perform transformations. <br>
# You can select the prefered methods to perform from the dropdowns provided in the excel sheet. <br>
# If a column is "Ordinal" then you have to provide the order of values also like below: <br>
# <pre>           <b>{'S':1,'A':2,'B':3,'C':4}</b></pre>
# In case of "Log Transformation" you have to provide multipler and addition like below: <br>
# <pre>           <b>multiplier|addition</b></pre>
# In case of "Adstock Transformation" you can give just an adstock value or if you want to give a lag also then input them like below:
# <pre>           <b>adstock|lag</b></pre>
#
# <b>If not generated</b><br>
# All the categorical columns are considered nominal

# %% [markdown]
# ## Generate Variable Profiling Sheet

# %% [markdown]
# #### If you want to perform quantile based binning

# %% [markdown]
# Performs variable profilling for a given dataset
#
# :param summary_path: File name of above generated excel file if not generated leave it <br>
# :param numerical_binning: Binning method to be performed <br>
# :param dep_var: Target variable <br>
# :param no_of_bins: Maximum number of bins allowed <br>
#
# :return: excel file which contains the variable profilling for the given dataset

# %%
excel_report.variable_profiling(summary_path='df_input.csv_eda_report_2.xlsx', numerical_binning='decile', dep_var='Target', no_of_bins=10)
# Out:
# transformation start
# transformation end
#
# numerical binning start
# 100%|███████████████████████████████████████████████████████████████████████████████| 292/292 [00:00<00:00, 358.21it/s]
# numerical binning end
#
# categorical binning start
# 100%|████████████████████████████████████████████████████████████████████████████████| 135/135 [00:04<00:00, 29.81it/s]
# categorical binning end
# saving
# Saved

# %% [markdown]
# #### If you want to perform tree-based binning

# %% [markdown]
# Performs variable profilling for a given dataset
#
# :param summary_path: File name of above generated excel file if not generated leave it <br>
# :param numerical_binning: Binning method to be performed <br>
# :param depth: Depth of tree <br>
# :param dep_var: Target variable <br>
# :param no_of_bins: Maximum number of bins allowed <br>
#
# :return: excel file which contains the variable profilling for the given dataset

# %%
excel_report.variable_profiling(summary_path='df_input.csv_eda_report_2.xlsx', numerical_binning='tree', depth=5, dep_var='Target', no_of_bins=10)
# Out:
# transformation start
# transformation end
#
# numerical binning start
# 100%|████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00,  7.32it/s]
# numerical binning end
#
# categorical binning start
# 100%|████████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 42.96it/s]
# categorical binning end
# saving
# Saved

# %% [markdown]
# The generated Variable Profiling Sheet have 3 sheets:
# <ul>
#   <li>Numierical Columns</li>
#   <li>Nominal Columns</li>
#   <li>Summary</li>
# </ul>
# If you have ordinal columns you will get another sheet named 'Ordinal Columns'. <br>
# In the Summary sheet you can filter the columns based on your requirement and click 'Apply Filter' button. <br>
# This button runs a vba code and shows only the columns pesent in Summary sheet in other sheets

# %% [markdown]
# #### Value based Binning

# %%
excel_report.variable_profiling(summary_path='df_input.csv_eda_report_2.xlsx', numerical_binning='value', dep_var='Target', no_of_bins=10)
# Out:
# transformation start
# transformation end
#
# numerical binning start
# 100%|████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 50.81it/s]
# numerical binning end
#
# categorical binning start
# 100%|████████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 60.53it/s]
# categorical binning end
# saving
# Saved

# %% [markdown]
# #### Naive Binning (Ordinal)

# %%
excel_report.variable_profiling(summary_path='df_input.csv_eda_report_2.xlsx', numerical_binning='decile', dep_var='Target', no_of_bins=10, ordinal_binning_type='naive', max_threshold=10, min_threshold=5, tolerence=0)
# Out:
# transformation start
# transformation end
#
# numerical binning start
# 100%|███████████████████████████████████████████████████████████████████████████████| 292/292 [00:01<00:00, 239.84it/s]
# numerical binning end
#
# categorical binning start
# 100%|████████████████████████████████████████████████████████████████████████████████| 134/134 [00:04<00:00, 27.13it/s]
# categorical binning end
# saving

# %% [markdown]
# #### Hierarchical Clustering (Ordinal)

# %%
excel_report.variable_profiling(summary_path='df_input.csv_eda_report_2.xlsx', numerical_binning='decile', dep_var='Target', no_of_bins=10, ordinal_binning_type='hierarchical', min_cluster_size=0.05, max_clusters=10)
# Out:
# transformation start
# transformation end
#
# numerical binning start
# 100%|███████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 249.99it/s]
# numerical binning end
#
# categorical binning start
# 100%|████████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 57.97it/s]
# categorical binning end
# saving
# Saved

# %% [markdown]
# #### K-prototype Clustering (Ordinal)

# %%
excel_report.variable_profiling(summary_path='df_input.csv_eda_report_2.xlsx', numerical_binning='decile', dep_var='Target', no_of_bins=10, ordinal_binning_type='kprototype', max_clusters=5)
# Out:
# transformation start
# transformation end
#
# numerical binning start
# 100%|███████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 299.99it/s]
# numerical binning end
#
# categorical binning start
# 100%|████████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 56.27it/s]
# categorical binning end
# saving
# Saved

# %% [markdown]
# ## Direct Binning

# %%
excel_report.variable_profiling(numerical_binning='decile', no_of_bins=10)
# Out:
# transformation start
# transformation end
#
# numerical binning start
# 100%|███████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 285.56it/s]
# numerical binning end
#
# categorical binning start
# 100%|███████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 334.09it/s]
# categorical binning end
# saving
# Saved

# %% [markdown]
# ## Generate Code

# %% [markdown]
# Generates a code, when executed gives the dataframe after all the transformations are done
#
# :param treatment_file: Initially generated summary file for a given data
#
# :return: Code which gives the transformed dataframe

# %%
excel_report.code_generator(treatment_file='df_input.csv_eda_report_2.xlsx')
# Out:
# df = pd.read_csv('df_input.csv')
# df = df.drop(['AP1999', 'IBE1801', 'IBE1802', 'IBE1805', 'IBE1806', 'IBE2000', 'IBE2001', 'IBE2002', 'IBE2003', 'IBE2004', 'IBE2005', 'IBE2006', 'IBE2007', 'IBE2008', 'IBE2009', 'IBE2010', 'IBE2011', 'IBE2012', 'IBE2013', 'IBE2014', 'IBE2015', 'IBE2016', 'IBE2017', 'IBE2018', 'IBE2019', 'IBE2020', 'IBE2021', 'IBE2022', 'IBE2023', 'IBE2024', 'IBE2025', 'IBE2026', 'IBE2029', 'IBE2031', 'IBE2032', 'IBE2033', 'IBE2058_01', 'IBE2058_02', 'IBE2059_01', 'IBE2059_02', 'IBE2060_01', 'IBE2060_02', 'IBE2061_01', 'IBE2061_02', 'IBE2062_01', 'IBE2062_02', 'IBE2076_01', 'IBE2076_02', 'IBE2076_03', 'IBE2076_04', 'IBE2076_05', 'IBE2076_06', 'IBE2076_07', 'IBE2076_08', 'IBE2076_09', 'IBE2076_10', 'IBE2076_11', 'IBE2076_12', 'IBE2076_13', 'IBE2077', 'IBE2081', 'IBE2083', 'IBE2085', 'IBE2086', 'IBE2089', 'IBE2090', 'IBE2091', 'IBE2092', 'IBE2093', 'IBE2095', 'IBE2096', 'IBE2098', 'IBE2150', 'IBE2151', 'IBE2152', 'IBE2155', 'IBE2158', 'IBE2160', 'IBE2162', 'IBE2163', 'IBE2165', 'IBE2166', 'IBE2168', 'IBE2170', 'IBE2172', 'IBE2173', 'IBE2176', 'IBE2177', 'IBE2178', 'IBE2179', 'IBE2180', 'IBE2182', 'IBE2183', 'IBE2185', 'IBE2192', 'IBE2193', 'IBE2194', 'IBE2205', 'IBE2206', 'IBE2208', 'IBE2350', 'IBE2351', 'IBE2354', 'IBE2356', 'IBE2362', 'IBE2365', 'IBE2367', 'IBE2369', 'IBE2370', 'IBE2372', 'IBE2373', 'IBE2507_01', 'IBE2507_02', 'IBE2508', 'IBE2509', 'IBE2510', 'IBE2522_01', 'IBE2522_02', 'IBE2524_01', 'IBE2524_02', 'IBE2527', 'IBE2529', 'IBE2531_01', 'IBE2531_02', 'IBE2532_01', 'IBE2532_02', 'IBE2753', 'IBE2757', 'IBE2758', 'IBE2760', 'IBE2776', 'IBE2807', 'IBE2810', 'IBE2890', 'IBE2891', 'IBE6102', 'IBE6103', 'IBE6104', 'IBE6107', 'IBE6134', 'IBE6135', 'IBE6136', 'IBE6137', 'IBE6138', 'IBE6139', 'IBE6140', 'IBE6141', 'IBE6142', 'IBE6143', 'IBE6144', 'IBE6145', 'IBE6146', 'IBE6147', 'IBE6148', 'IBE6149', 'IBE6150', 'IBE6151', 'IBE6152', 'IBE6154', 'IBE6155', 'IBE6156', 'IBE6157', 'IBE6165', 'IBE6166', 'IBE6167', 'IBE6168', 'IBE6169', 'IBE6170', 'IBE6171', 'IBE6172', 'IBE6173', 'IBE6174', 'IBE6175', 'IBE6176', 'IBE6177', 'IBE6178', 'IBE6179', 'IBE6180', 'IBE6182', 'IBE6183', 'IBE6184', 'IBE6185', 'IBE6186', 'IBE6187', 'IBE6188', 'IBE6189', 'IBE6190', 'IBE6191', 'IBE6192', 'IBE6193', 'IBE6195', 'IBE6196', 'IBE6197', 'IBE6198', 'IBE6199', 'IBE6200', 'IBE6201', 'IBE6202', 'IBE6203', 'IBE6204', 'IBE6205', 'IBE6206', 'IBE6207', 'IBE6208', 'IBE6209', 'IBE6210', 'IBE6211', 'IBE6212', 'IBE6213', 'IBE6214', 'IBE6215', 'IBE6216', 'IBE6217', 'IBE6220', 'IBE6221', 'IBE6222', 'IBE6223', 'IBE6224', 'IBE6225', 'IBE6226', 'IBE6227', 'IBE6228', 'IBE6229', 'IBE6230', 'IBE6231', 'IBE6232', 'IBE6233', 'IBE6234', 'IBE6235', 'IBE6236', 'IBE6237', 'IBE6239', 'IBE6240', 'IBE6241', 'IBE6242', 'IBE6243', 'IBE6244', 'IBE6245', 'IBE6246', 'IBE6247', 'IBE6248', 'IBE6249', 'IBE6250', 'IBE6251', 'IBE6252', 'IBE6253', 'IBE6254', 'IBE6255', 'IBE6256', 'IBE6257', 'IBE6258', 'IBE6259', 'IBE6260', 'IBE6261', 'IBE6262', 'IBE6263', 'IBE6265', 'IBE6266', 'IBE6267', 'IBE6268', 'IBE6269', 'IBE6270', 'IBE6271', 'IBE6272', 'IBE6273', 'IBE6274', 'IBE6275', 'IBE6276', 'IBE6277', 'IBE6278', 'IBE6279', 'IBE6280', 'IBE6281', 'IBE6282', 'IBE6283', 'IBE6285', 'IBE6286', 'IBE6289', 'IBE6291', 'IBE6292', 'IBE6293', 'IBE6294', 'IBE6295', 'IBE6296', 'IBE6297', 'IBE6298', 'IBE6300', 'IBE6301', 'IBE6302', 'IBE6303', 'IBE6305', 'IBE6308', 'IBE6309', 'IBE6311', 'IBE6312', 'IBE6313', 'IBE6314', 'IBE6315', 'IBE6316', 'IBE6317', 'IBE6318', 'IBE6319', 'IBE6320', 'IBE6322', 'IBE6323', 'IBE6324', 'IBE6325', 'IBE6326', 'IBE6328', 'IBE6329', 'IBE6330', 'IBE6331', 'IBE6332', 'IBE6333', 'IBE6334', 'IBE6335', 'IBE6336', 'IBE6337', 'IBE6338', 'IBE6339', 'IBE6341', 'IBE6342', 'IBE6343', 'IBE6344', 'IBE6345', 'IBE6346', 'IBE6347', 'IBE6348', 'IBE6349', 'IBE6350', 'IBE6351', 'IBE6354', 'IBE6358', 'IBE6359', 'IBE6360', 'IBE6361', 'IBE6362', 'IBE6365', 'IBE6366', 'IBE6367', 'IBE6368', 'IBE6369', 'IBE6370', 'IBE6371', 'IBE6372', 'IBE6373', 'IBE6374', 'IBE6375', 'IBE6376', 'IBE6377', 'IBE6378', 'IBE6379', 'IBE6380', 'IBE6 ...
# df['IBE8661_01'] = df['IBE8661_01'].fillna('MICHAEL')
# df['IBE8747'] = df['IBE8747'].fillna(230682.82)
# df['IBE8594'] = df['IBE8594'].fillna('8.00E+17')
# df['IBE2361'] = df['IBE2361'].fillna(4458.33)
# df['IBE8707'] = df['IBE8707'].fillna(406647.95)
# df['IBE8706'] = df['IBE8706'].fillna(241518.97)
# df['IBE8702'] = df['IBE8702'].fillna(610472.34)
# df['IBE6867'] = df['IBE6867'].fillna(396.25)
# df['IBE2762'] = df['IBE2762'].fillna(396.25)
# df['IBE2195'] = df['IBE2195'].fillna(1342.73)
# df['IBE8660_01'] = df['IBE8660_01'].fillna('MICHAEL')
# df['IBE2363'] = df['IBE2363'].fillna(715.34)
# df['IBE2364'] = df['IBE2364'].fillna(332.1)
# df['IBE2770'] = df['IBE2770'].fillna(365.41)
# df['IBE6868'] = df['IBE6868'].fillna(414.25)
# df['IBE2763'] = df['IBE2763'].fillna(414.25)
# df['IBE8708'] = df['IBE8708'].fillna(515874.2)
# df['IBE6878'] = df['IBE6878'].fillna(412.35)
# df['IBE6859'] = df['IBE6859'].fillna(373.8)
# df['IBE2371'] = df['IBE2371'].fillna(629.26)
# df['IBE8713'] = df['IBE8713'].fillna(361884.37)
# df['IBE6854'] = df['IBE6854'].fillna(359.56)
# df['IBE2771'] = df['IBE2771'].fillna(361.3)
# df['IBE8565'] = df['IBE8565'].fillna('J P MORGAN CHASE BANK')
# df['IBE2190'] = df['IBE2190'].fillna(204.41)
# df['IBE9750'] = df['IBE9750'].fillna(1047193.19)
# df['IBE2189'] = df['IBE2189'].fillna(310.89)
# df['IBE2184'] = df['IBE2184'].fillna(825.2)
# df['IBE8705'] = df['IBE8705'].fillna(743919.83)
# df['IBE8446'] = df['IBE8446'].fillna(9489.94)
# df['IBE2759'] = df['IBE2759'].fillna(290.65)
# df['IBE6856'] = df['IBE6856'].fillna(381.79)
# df['IBE2765'] = df['IBE2765'].fillna(457.83)
# df['IBE8588'] = df['IBE8588'].fillna(3146.09)
# df['IBE2188'] = df['IBE2188'].fillna(270.54)
# df['IBE2767'] = df['IBE2767'].fillna(408.55)
# df['IBE2169'] = df['IBE2169'].fillna(302.06)
# df['IBE8612_01'] = df['IBE8612_01'].fillna('ELIZABETH')
# df['IBE8589'] = df['IBE8589'].fillna(136595.5)
# df['IBE2773'] = df['IBE2773'].fillna(305.47)
# df['IBE6870'] = df['IBE6870'].fillna(399.43)
# df['IBE2755'] = df['IBE2755'].fillna(471.91)
# df['IBE2191'] = df['IBE2191'].fillna(103.69)
# df['IBE2768'] = df['IBE2768'].fillna(496.68)
# df['IBE6875'] = df['IBE6875'].fillna(370.83)
# df['IBE2171'] = df['IBE2171'].fillna(660.78)
# df['IBE2366'] = df['IBE2366'].fillna(136.31)
# df['IBE2181'] = df['IBE2181'].fillna(388.26)
# df['IBE8564'] = df['IBE8564'].fillna('BANK OF AMERICA')
# df['IBE2769'] = df['IBE2769'].fillna(380.46)
# df['IBE6813'] = df['IBE6813'].fillna(3224.3)
# df['IBE6866'] = df['IBE6866'].fillna(357.94)
# df['IBE2761'] = df['IBE2761'].fillna(329.25)
# df['IBE6355'] = df['IBE6355'].fillna(20090440.49)
# df['IBE2175'] = df['IBE2175'].fillna(354.33)
# df['IBE2751'] = df['IBE2751'].fillna(265.28)
# df['IBE6357'] = df['IBE6357'].fillna(20085151.12)
# df['IBE2368'] = df['IBE2368'].fillna(1157.24)
# df['IBE2774'] = df['IBE2774'].fillna(335.18)
# df['IBE6869'] = df['IBE6869'].fillna(395.02)
# df['IBE2187'] = df['IBE2187'].fillna(190.5)
# df['IBE8610_01'] = df['IBE8610_01'].fillna('MICHAEL')
# df['IBE6708'] = df['IBE6708'].fillna(1287.23)
# df['IBE2772'] = df['IBE2772'].fillna(229.52)
# df['IBE2764'] = df['IBE2764'].fillna(329.09)
# df['IBE8558'] = df['IBE8558'].fillna(51.23)
# df['IBE2167'] = df['IBE2167'].fillna(928.79)
# df['IBE2174'] = df['IBE2174'].fillna(572.24)
# df['IBE6686'] = df['IBE6686'].fillna(2273.66)
# df['IBE2754'] = df['IBE2754'].fillna(268.92)
# df['IBE8840'] = df['IBE8840'].fillna(29115.89)
# df['IBE6356'] = df['IBE6356'].fillna(20171182.17)
# df['IBE2766'] = df['IBE2766'].fillna(286.26)
# df['IBE6533'] = df['IBE6533'].fillna(20188218.03)
# df['IBE6863'] = df['IBE6863'].fillna(266.97)
# df['IBE6121'] = df['IBE6121'].fillna(525.16)
# df['IBE6132'] = df['IBE6132'].fillna(469.8)
# df['IBE6128'] = df['IBE6128'].fillna(536.44)
# df['IBE8579'] = df['IBE8579'].fillna(200912.49)
# df['IBE2186'] = df['IBE2186'].fillna(104.48)
# df['IBE6532'] = df['IBE6532'].fillna(20193324.21)
# df['IBE6858'] = df['IBE6858'].fillna(261.89)
# df['IBE6131'] = df['IBE6131'].fillna(543.52)
# df['IBE6129'] = df['IBE6129'].fillna(558.98)
# df['IBE6127'] = df['IBE6127'].fillna(494.46)
# df['IBE6130'] = df['IBE6130'].fillna(571.24)
# df['IBE6122'] = df['IBE6122'].fillna(459.54)
# df['IBE6124'] = df['IBE6124'].fillna(451.76)
# df['IBE6123'] = df['IBE6123'].fillna(653.42)
# df['IBE6125'] = df['IBE6125'].fillna(464.76)
# df['IBE6126'] = df['IBE6126'].fillna(454.88)
# df['IBE6865'] = df['IBE6865'].fillna(287.32)
# df['IBE9054'] = df['IBE9054'].fillna('GRAND CHEROKEE')
# df['IBE6535'] = df['IBE6535'].fillna(20198664.03)
# df['IBE2752'] = df['IBE2752'].fillna(233.37)
# df['IBE9044'] = df['IBE9044'].fillna('GRAND CHEROKEE')
# df['IBE8643'] = df['IBE8643'].fillna(200616.47)
# df['IBE2756'] = df['IBE2756'].fillna(260.66)
# df['IBE6161'] = df['IBE6161'].fillna(407.8)
# df['IBE6163'] = df['IBE6163'].fillna(203.94)
# df['IBE6685'] = df['IBE6685'].fillna(426.9)
# df['IBE8704'] = df['IBE8704'].fillna(61.93)
# df['IBE9057'] = df['IBE9057'].fillna(20190157.83)
# df['IBE6853'] = df['IBE6853'].fillna(207.22)
# df['IBE6840'] = df['IBE6840'].fillna(197.41)
# df['IBE6872'] = df['IBE6872'].fillna(99.31)
# df['IBE6707'] = df['IBE6707'].fillna(217.1)
# df['IBE6843'] = df['IBE6843'].fillna(133.1)
# df['IBE6162'] = df['IBE6162'].fillna(124.24)
# df['IBE8559'] = df['IBE8559'].fillna(33.51)
# df['IBE8580'] = df['IBE8580'].fillna(2009.06)
# df['IBE2157'] = df['IBE2157'].fillna(2.93)
# df['IBE9751'] = df['IBE9751'].fillna(11.86)
# df['IBE6841'] = df['IBE6841'].fillna(175.89)
# df['IBE6844'] = df['IBE6844'].fillna(107.56)
# df['IBE2097'] = df['IBE2097'].fillna(4.89)
# df['IBE2360'] = df['IBE2360'].fillna('D023')
# df['IBE8691_01'] = df['IBE8691_01'].fillna(1976.43)
# df['IBE6164'] = df['IBE6164'].fillna(110.4)
# df['IBE6842'] = df['IBE6842'].fillna(163.9)
# df['IBE9047'] = df['IBE9047'].fillna(20194062.21)
# df['IBE8562_01'] = df['IBE8562_01'].fillna(2013.27)
# df['IBE8607'] = df['IBE8607'].fillna(8.29)
# df['IBE6845'] = df['IBE6845'].fillna(80.1)
# df['IBE8592'] = df['IBE8592'].fillna(1957.96)
# df['IBE6106'] = df['IBE6106'].fillna(2.71)
# df['IBE8582'] = df['IBE8582'].fillna(9.2)
# df['IBE7607_01'] = df['IBE7607_01'].fillna(8.15)
# df['IBE2403_01'] = df['IBE2403_01'].fillna(8.96)
# df['IBE8436'] = df['IBE8436'].fillna('J')
# df['IBE8644'] = df['IBE8644'].fillna(2006.1)
# df['IBE2148'] = df['IBE2148'].fillna(3.15)
# df['IBE8434_01'] = df['IBE8434_01'].fillna(2013.84)
# df['IBE9051'] = df['IBE9051'].fillna(39.43)
# df['TP000105'] = df['TP000105'].fillna(70.75)
# df['IBE2149'] = df['IBE2149'].fillna(2.06)
# df['IBE9160_01'] = df['IBE9160_01'].fillna(20185572.5)
# df['IBE9159_01'] = df['IBE9159_01'].fillna(20189194.25)
# df['IBE9158_01'] = df['IBE9158_01'].fillna(20192085.93)
# df['IBE6720'] = df['IBE6720'].fillna(3.16)
# df['IBE8623_01'] = df['IBE8623_01'].fillna(1968.25)
# df['IBE8618_01'] = df['IBE8618_01'].fillna(1965.35)
# df['IBE8444'] = df['IBE8444'].fillna(28.28)
# df['IBE2161'] = df['IBE2161'].fillna(11.39)
# df['IBE9157_01'] = df['IBE9157_01'].fillna(20195927.17)
# df['IBE1273_01'] = df['IBE1273_01'].fillna(8.22)
# df['IBE6814'] = df['IBE6814'].fillna(24.98)
# df['IBE7606_02'] = df['IBE7606_02'].fillna('3')
# df['IBE9152'] = df['IBE9152'].fillna(20199254.48)
# df['IBE9156_01'] = df['IBE9156_01'].fillna(20199254.48)
# df['IBE9041'] = df['IBE9041'].fillna(38.91)
# df['IBE2082'] = df['IBE2082'].fillna(3.31)
# df['IBE8626'] = df['IBE8626'].fillna(52.14)
# df['IBE6718'] = df['IBE6718'].fillna(6.54)
# df['AP008728'] = df['AP008728'].fillna(3.34)
# df['PX001270_01'] = df['PX001270_01'].fillna(8.34)
# df['TP000620'] = df['TP000620'].fillna(34.54)
# df['AP000903'] = df['AP000903'].fillna(5.49)
# df['IBE8568'] = df['IBE8568'].fillna('H')
# df['IBE8682'] = df['IBE8682'].fillna(43.91)
# df['IBE6105'] = df['IBE6105'].fillna(2.32)
# df['IBE8442'] = df['IBE8442'].fillna(7.8)
# df['AP003595'] = df['AP003595'].fillna(3.69)
# df['TP000159'] = df['TP000159'].fillna(64.7)
# df['IBE8611_01'] = df['IBE8611_01'].fillna(1967.93)
# df['IBE2147'] = df['IBE2147'].fillna(2.46)
# df['IBE7616_01'] = df['IBE7616_01'].fillna(52.18)
# df['IBE8586'] = df['IBE8586'].fillna('A')
# df['IBE7110'] = df['IBE7110'].fillna(6.63)
# df['IBE6722'] = df['IBE6722'].fillna(3.12)
# df['IBE6609'] = df['IBE6609'].fillna(12.9)
# df['IBE8584'] = df['IBE8584'].fillna('J')
# df['IBE8557'] = df['IBE8557'].fillna('A')
# df['AP003594'] = df['AP003594'].fillna(4.07)
# df['PX001271_01'] = df['PX001271_01'].fillna('11B')
# df['IBE8561'] = df['IBE8561'].fillna('K')
# df['IBE8581'] = df['IBE8581'].fillna('A')
# df['IBE8585'] = df['IBE8585'].fillna('P')
# df['IBE8567'] = df['IBE8567'].fillna('O')
# df['IBE8617'] = df['IBE8617'].fillna(55.02)
# df['AP001154'] = df['AP001154'].fillna(6.29)
# df['IBE9533'] = df['IBE9533'].fillna('O')
# df['IBE6721'] = df['IBE6721'].fillna(2.07)
# df['AP001181'] = df['AP001181'].fillna(3.23)
# df['IBE2153'] = df['IBE2153'].fillna(1.88)
# df['IBE9350'] = df['IBE9350'].fillna(6.26)
# df['IBE2885'] = df['IBE2885'].fillna('A')
# df['IBE8616'] = df['IBE8616'].fillna(52.46)
# df['AP003591'] = df['AP003591'].fillna(7.12)
# df['PX001274_01'] = df['PX001274_01'].fillna('01C')
# df['AP006251_01'] = df['AP006251_01'].fillna(82.94)
# df['AP003592'] = df['AP003592'].fillna(7.47)
# df['TP000559'] = df['TP000559'].fillna(22.67)
# df['IBE8438'] = df['IBE8438'].fillna('O')
# df['IBE8819_01'] = df['IBE8819_01'].fillna(2014.54)
# df['AP008729'] = df['AP008729'].fillna(2.38)
# df['IBE9356'] = df['IBE9356'].fillna('B')
# df['AP008717'] = df['AP008717'].fillna(2.87)
# df['IBE6603'] = df['IBE6603'].fillna(3.69)
# df['IBE8437'] = df['IBE8437'].fillna('O')
# df['IBE7606_01'] = df['IBE7606_01'].fillna('O')
# df['IBE2145'] = df['IBE2145'].fillna(2.27)
# df['IBE2144'] = df['IBE2144'].fillna(1.73)
# df['AP003587'] = df['AP003587'].fillna(4.89)
# df['IBE9358'] = df['IBE9358'].fillna(3.66)
# df['AP006249_01'] = df['AP006249_01'].fillna(4.75)
# df['IBE8560'] = df['IBE8560'].fillna(8.26)
# df['IBE6697'] = df['IBE6697'].fillna(1.82)
# df['IBE9050'] = df['IBE9050'].fillna(40.47)
# df['IBE9053'] = df['IBE9053'].fillna('HONDA')
# df['IBE9040'] = df['IBE9040'].fillna(41.42)
# df['IBE9043'] = df['IBE9043'].fillna('HONDA')
# df['TP000550'] = df['TP000550'].fillna(22.68)
# df['IBE4000'] = df['IBE4000'].fillna(6.51)
# df['IBE8441'] = df['IBE8441'].fillna('G')
# df['IBE8663'] = df['IBE8663'].fillna('K')
# df['AP003446'] = df['AP003446'].fillna(3.9)
# df['IBE7629_01'] = df['IBE7629_01'].fillna(2.8)
# df['IBE6696'] = df['IBE6696'].fillna(12.12)
# df['IBE8629'] = df['IBE8629'].fillna(2.8)
# df['TP000546'] = df['TP000546'].fillna(24.75)
# df['IBE2164'] = df['IBE2164'].fillna(1.76)
# df['TP000158'] = df['TP000158'].fillna(30.91)
# df['IBE9351'] = df['IBE9351'].fillna(16.4)
# df['IBE2094'] = df['IBE2094'].fillna(3.61)
# df['IBE7609_01'] = df['IBE7609_01'].fillna('M')
# df['IBE9528'] = df['IBE9528'].fillna('O')
# df['IBE8609'] = df['IBE8609'].fillna('M')
# df['IBE6608'] = df['IBE6608'].fillna(3.52)
# df['IBE7628_01'] = df['IBE7628_01'].fillna(2.12)
# df['IBE2154'] = df['IBE2154'].fillna(2.12)
# df['IBE8614'] = df['IBE8614'].fillna(20212.96)
# df['IBE8628'] = df['IBE8628'].fillna(2.13)
# df['IBE7607_02'] = df['IBE7607_02'].fillna('3')
# df['IBE4100'] = df['IBE4100'].fillna(7.72)
# df['IBE2156'] = df['IBE2156'].fillna(2.01)
# df['IBE8660_02'] = df['IBE8660_02'].fillna('M')
# df['IBE2084'] = df['IBE2084'].fillna(3.81)
# df['AP003447'] = df['AP003447'].fillna(2.74)
# df['AP001238'] = df['AP001238'].fillna(5.81)
# df['IBE2146'] = df['IBE2146'].fillna(1.97)
# df['IBE9181'] = df['IBE9181'].fillna('U4')
# df['IBE2080'] = df['IBE2080'].fillna(5.76)
# df['IBE8597'] = df['IBE8597'].fillna(3.77)
# df['IBE2886'] = df['IBE2886'].fillna('A')
# df['IBE2881'] = df['IBE2881'].fillna('A')
# df['IBE6723'] = df['IBE6723'].fillna(1.55)
# df['IBE8562_02'] = df['IBE8562_02'].fillna(6.36)
# df['IBE6724'] = df['IBE6724'].fillna(2.91)
# df['IBE2892'] = df['IBE2892'].fillna('A')
# df['IBE6118'] = df['IBE6118'].fillna(2.93)
# df['IBE8463'] = df['IBE8463'].fillna(3.45)
# df['IBE7602_02'] = df['IBE7602_02'].fillna('3')
# df['IBE7622_02'] = df['IBE7622_02'].fillna('3')
# df['AP006250_01'] = df['AP006250_01'].fillna(3.43)
# df['IBE9180'] = df['IBE9180'].fillna('U4')
# df['IBE2159'] = df['IBE2159'].fillna(2.0)
# df['IBE2088'] = df['IBE2088'].fillna(2.21)
# df['IBE6700'] = df['IBE6700'].fillna(5.64)
# df['IBE6719'] = df['IBE6719'].fillna(1.6)
# df['IBE8637'] = df['IBE8637'].fillna('1')
# df['IBE6604'] = df['IBE6604'].fillna(3.26)
# df['IBE2888'] = df['IBE2888'].fillna('A')
# df['IBE2887'] = df['IBE2887'].fillna('A')
# df['AP008727'] = df['AP008727'].fillna(2.55)
# df['AP006246_02'] = df['AP006246_02'].fillna('1')
# df['AP006251_02'] = df['AP006251_02'].fillna('1')
# df['AP006250_02'] = df['AP006250_02'].fillna('1')
# df['AP006249_02'] = df['AP006249_02'].fillna('1')
# df['IBE2087'] = df['IBE2087'].fillna(4.38)
# df['IBE8763'] = df['IBE8763'].fillna('B')
# df['IBE6702'] = df['IBE6702'].fillna(6.27)
# df['IBE6114'] = df['IBE6114'].fillna(2.78)
# df['IBE8440'] = df['IBE8440'].fillna('B')
# df['IBE8443'] = df['IBE8443'].fillna('B')
# df['IBE6116'] = df['IBE6116'].fillna(2.9)
# df['IBE6119'] = df['IBE6119'].fillna(2.66)
# df['IBE6605'] = df['IBE6605'].fillna(3.07)
# df['IBE8604'] = df['IBE8604'].fillna('1')
# df['IBE8612_02'] = df['IBE8612_02'].fillna('M')
# df['IBE8531'] = df['IBE8531'].fillna('D')
# df['IBE9052'] = df['IBE9052'].fillna(2009.25)
# df['AP003593'] = df['AP003593'].fillna(8.81)
# df['IBE6111'] = df['IBE6111'].fillna(2.61)
# df['IBE8575'] = df['IBE8575'].fillna('L')
# df['IBE6698'] = df['IBE6698'].fillna(4.13)
# df['IBE2884'] = df['IBE2884'].fillna('A')
# df['IBE6117'] = df['IBE6117'].fillna(3.15)
# df['IBE6108'] = df['IBE6108'].fillna(2.8)
# df['IBE6611'] = df['IBE6611'].fillna(3.68)
# df['AP002781'] = df['AP002781'].fillna(3.13)
# df['IBE7616_02'] = df['IBE7616_02'].fillna('3')
# df['IBE7600_22'] = df['IBE7600_22'].fillna('3')
# df['AP003588'] = df['AP003588'].fillna(2.77)
# df['IBE2800'] = df['IBE2800'].fillna(2.57)
# df['IBE8642'] = df['IBE8642'].fillna('Q')
# df['IBE6112'] = df['IBE6112'].fillna(2.8)
# df['AP001241'] = df['AP001241'].fillna(7.34)
# df['IBE8605'] = df['IBE8605'].fillna('1')
# df['IBE6699'] = df['IBE6699'].fillna(2.24)
# df['IBE8839_01'] = df['IBE8839_01'].fillna(2019.87)
# df['IBE7641_02'] = df['IBE7641_02'].fillna('3')
# df['IBE6701'] = df['IBE6701'].fillna(1.74)
# df['IBE7650_02'] = df['IBE7650_02'].fillna('3')
# df['IBE8487'] = df['IBE8487'].fillna('D')
# df['IBE2883'] = df['IBE2883'].fillna('E')
# df['AP005423'] = df['AP005423'].fillna(4.45)
# df['IBE8625'] = df['IBE8625'].fillna('C')
# df['IBE8570'] = df['IBE8570'].fillna('R')
# df['AP001216'] = df['AP001216'].fillna(12.97)
# df['IBE9158_02'] = df['IBE9158_02'].fillna('A4')
# df['IBE8819_02'] = df['IBE8819_02'].fillna(6.62)
# df['IBE2875'] = df['IBE2875'].fillna('A')
# df['IBE8816'] = df['IBE8816'].fillna(5.47)
# df['AP008718'] = df['AP008718'].fillna(4.91)
# df['IBE7602_01'] = df['IBE7602_01'].fillna(0.75)
# df['AP000920'] = df['AP000920'].fillna(9.53)
# df['IBE8608'] = df['IBE8608'].fillna('S')
# df['IBE8671'] = df['IBE8671'].fillna('D')
# df['AP002778'] = df['AP002778'].fillna(5.05)
# df['IBE6109'] = df['IBE6109'].fillna(2.56)
# df['AP005385'] = df['AP005385'].fillna(15.02)
# df['IBE8439'] = df['IBE8439'].fillna('B')
# df['IBE8590_01'] = df['IBE8590_01'].fillna(6.49)
# df['IBE8434_02'] = df['IBE8434_02'].fillna(6.49)
# df['AP003590'] = df['AP003590'].fillna(7.9)
# df['IBE8652'] = df['IBE8652'].fillna(1.73)
# df['IBE6113'] = df['IBE6113'].fillna(2.67)
# df['IBE3102'] = df['IBE3102'].fillna('40')
# df['IBE8201'] = df['IBE8201'].fillna('F')
# df['AP000953'] = df['AP000953'].fillna(14.62)
# df['IBE6115'] = df['IBE6115'].fillna(2.84)
# df['IBE2879'] = df['IBE2879'].fillna('A')
# df['IBE2878'] = df['IBE2878'].fillna('B')
# df['IBE8610_03'] = df['IBE8610_03'].fillna('M')
# df['IBE6110'] = df['IBE6110'].fillna(3.57)
# df['AP006332'] = df['AP006332'].fillna(10.16)
# df['IBE8691_02'] = df['IBE8691_02'].fillna(6.38)
# df['IBE2860'] = df['IBE2860'].fillna('E')
# df['IBE2874'] = df['IBE2874'].fillna('K')
# df['IBE9156_02'] = df['IBE9156_02'].fillna('A5')
# df['IBE8610_02'] = df['IBE8610_02'].fillna('A')
# df['IBE2870'] = df['IBE2870'].fillna('E')
# df['IBE9515'] = df['IBE9515'].fillna('M')
# df['IBE2866'] = df['IBE2866'].fillna('E')
# df['AP002897'] = df['AP002897'].fillna(3.24)
# df['IBE8641'] = df['IBE8641'].fillna(8.42)
# df['IBE8688'] = df['IBE8688'].fillna('F')
# df['IBE7622_01'] = df['IBE7622_01'].fillna('N')
# df['IBE9042'] = df['IBE9042'].fillna(2009.81)
# df['IBE9509'] = df['IBE9509'].fillna(1.8)
# df['AP003448'] = df['AP003448'].fillna(5.4)
# df['IBE8850'] = df['IBE8850'].fillna(2.15)
# df['IBE2871'] = df['IBE2871'].fillna('E')
# df['IBE2867'] = df['IBE2867'].fillna('E')
# df['IBE2877'] = df['IBE2877'].fillna('A')
# df['AP001242'] = df['AP001242'].fillna(13.03)
# df['IBE9511'] = df['IBE9511'].fillna(1.48)
# df['IBE8611_02'] = df['IBE8611_02'].fillna(6.39)
# df['IBE2861'] = df['IBE2861'].fillna('E')
# df['IBE8602'] = df['IBE8602'].fillna(1.02)
# df['IBE2889'] = df['IBE2889'].fillna('A')
# df['IBE2868'] = df['IBE2868'].fillna('E')
# df['IBE2863'] = df['IBE2863'].fillna('E')
# df['IBE2864'] = df['IBE2864'].fillna('E')
# df['IBE9150_06'] = df['IBE9150_06'].fillna(1.66)
# df['IBE9154'] = df['IBE9154'].fillna('A4')
# df['IBE9150_03'] = df['IBE9150_03'].fillna(1.48)
# df['IBE8618_02'] = df['IBE8618_02'].fillna(6.42)
# df['AP002779'] = df['AP002779'].fillna(1.73)
# df['IBE2876'] = df['IBE2876'].fillna('A')
# df['AP003589'] = df['AP003589'].fillna(7.82)
# df['AP001218'] = df['AP001218'].fillna(2.49)
# df['IBE8590_02'] = df['IBE8590_02'].fillna(6.74)
# df['IBE9514'] = df['IBE9514'].fillna(1.79)
# df['IBE9159_02'] = df['IBE9159_02'].fillna('A4')
# df['AP002780'] = df['AP002780'].fillna(3.9)
# df['IBE9160_02'] = df['IBE9160_02'].fillna('A4')
# df['IBE7650_01'] = df['IBE7650_01'].fillna(1.89)
# df['IBE2869'] = df['IBE2869'].fillna('E')
# df['IBE7641_01'] = df['IBE7641_01'].fillna(8.44)
# df['IBE9157_02'] = df['IBE9157_02'].fillna('A4')
# df['IBE2873'] = df['IBE2873'].fillna('H')
# df['IBE1273_02'] = df['IBE1273_02'].fillna('E')
# df['IBE9641'] = df['IBE9641'].fillna(8.44)
# df['IBE8572'] = df['IBE8572'].fillna('F')
# df['IBE2872'] = df['IBE2872'].fillna('E')
# df['IBE8623_02'] = df['IBE8623_02'].fillna(6.42)
# df['IBE8612_03'] = df['IBE8612_03'].fillna('F')
# df['IBE9516'] = df['IBE9516'].fillna('F')
# df['IBE2865'] = df['IBE2865'].fillna('E')
# df['IBE8658'] = df['IBE8658'].fillna('E')
# df['IBE2880'] = df['IBE2880'].fillna('B')
# df['IBE2862'] = df['IBE2862'].fillna('E')
# df['IBE7609_02'] = df['IBE7609_02'].fillna('3')
# df['IBE9150_07'] = df['IBE9150_07'].fillna(3.27)
# df['IBE8645'] = df['IBE8645'].fillna(6.64)
# df['IBE2882'] = df['IBE2882'].fillna('E')
# df['IBE8647'] = df['IBE8647'].fillna(1.85)
# df['IBE9150_04'] = df['IBE9150_04'].fillna(1.37)
# df['IBE9518'] = df['IBE9518'].fillna('F')
# df['IBE8496'] = df['IBE8496'].fillna('D')
# df['IBE8661_03'] = df['IBE8661_03'].fillna('F')
# df['IBE9150_05'] = df['IBE9150_05'].fillna(1.89)
# df['IBE9150_02'] = df['IBE9150_02'].fillna(1.3)
# df['IBE3103'] = df['IBE3103'].fillna('X')
# df['IBE2526'] = df['IBE2526'].fillna(1.41)
# df['AP006246_01'] = df['AP006246_01'].fillna(1.16)
# df['IBE3101'] = df['IBE3101'].fillna('W')
# df['IBE7628_02'] = df['IBE7628_02'].fillna('3')
# df['IBE7601_16'] = df['IBE7601_16'].fillna('4')
# df['IBE8701'] = df['IBE8701'].fillna('R')
# df['PX001271_02'] = df['PX001271_02'].fillna('3')
# df['PX001270_02'] = df['PX001270_02'].fillna('3')
# df['PX001274_02'] = df['PX001274_02'].fillna('3')
# df['IBE7629_02'] = df['IBE7629_02'].fillna('3')
# df['IBE9510'] = df['IBE9510'].fillna(1.84)
# df['IBE8839_02'] = df['IBE8839_02'].fillna(5.67)
# df['IBE8505'] = df['IBE8505'].fillna('D')
# df['IBE8660_03'] = df['IBE8660_03'].fillna('F')
# df['IBE8657'] = df['IBE8657'].fillna('A')
# df['IBE8622'] = df['IBE8622'].fillna('Y')
# df['IBE8606'] = df['IBE8606'].fillna('O')
# df['IBE8555'] = df['IBE8555'].fillna('O')
# df['IBE8576'] = df['IBE8576'].fillna('E')
# df['IBE9517'] = df['IBE9517'].fillna('F')
# df['Target'] = df['Target'].fillna(0)
#
# df['IBE8747'] = np.where(df['IBE8747'] >= 230682.82, 230682.82, np.where(df['IBE8747'] <= 230682.82, 230682.82, df['IBE8747']))
# df['IBE2361'] = np.where(df['IBE2361'] >= 4458.33, 4458.33, np.where(df['IBE2361'] <= 4458.33, 4458.33, df['IBE2361']))
# df['IBE8707'] = np.where(df['IBE8707'] >= 406647.95, 406647.95, np.where(df['IBE8707'] <= 406647.95, 406647.95, df['IBE8707']))
# df['IBE8706'] = np.where(df['IBE8706'] >= 241518.97, 241518.97, np.where(df['IBE8706'] <= 241518.97, 241518.97, df['IBE8706']))
# df['IBE8702'] = np.where(df['IBE8702'] >= 656180.8499999999, 656180.8499999999, np.where(df['IBE8702'] <= 534291.49, 534291.49, df['IBE8702']))
# df['IBE6867'] = np.where(df['IBE6867'] >= 396.25, 396.25, np.where(df['IBE6867'] <= 396.25, 396.25, df['IBE6867']))
# df['IBE2762'] = np.where(df['IBE2762'] >= 396.25, 396.25, np.where(df['IBE2762'] <= 396.25, 396.25, df['IBE2762']))
# df['IBE2195'] = np.where(df['IBE2195'] >= 1342.73, 1342.73, np.where(df['IBE2195'] <= 1342.73, 1342.73, df['IBE2195']))
# df['IBE2363'] = np.where(df['IBE2363'] >= 715.34, 715.34, np.where(df['IBE2363'] <= 715.34, 715.34, df['IBE2363']))
# df['IBE2364'] = np.where(df['IBE2364'] >= 332.1, 332.1, np.where(df['IBE2364'] <= 332.1, 332.1, df['IBE2364']))
# df['IBE2770'] = np.where(df['IBE2770'] >= 365.41, 365.41, np.where(df['IBE2770'] <= 365.41, 365.41, df['IBE2770']))
# df['IBE6868'] = np.where(df['IBE6868'] >= 414.25, 414.25, np.where(df['IBE6868'] <= 414.25, 414.25, df['IBE6868']))
# df['IBE2763'] = np.where(df['IBE2763'] >= 414.25, 414.25, np.where(df['IBE2763'] <= 414.25, 414.25, df['IBE2763']))
# df['IBE8708'] = np.where(df['IBE8708'] >= 538185.5, 538185.5, np.where(df['IBE8708'] <= 478688.69999999995, 478688.69999999995, df['IBE8708']))
# df['IBE6878'] = np.where(df['IBE6878'] >= 412.35, 412.35, np.where(df['IBE6878'] <= 412.35, 412.35, df['IBE6878']))
# df['IBE6859'] = np.where(df['IBE6859'] >= 373.8, 373.8, np.where(df['IBE6859'] <= 373.8, 373.8, df['IBE6859']))
# df['IBE2371'] = np.where(df['IBE2371'] >= 629.26, 629.26, np.where(df['IBE2371'] <= 629.26, 629.26, df['IBE2371']))
# df['IBE8713'] = np.where(df['IBE8713'] >= 915840.0, 915840.0, np.where(df['IBE8713'] <= -506400.0, -506400.0, df['IBE8713']))
# df['IBE6854'] = np.where(df['IBE6854'] >= 359.56, 359.56, np.where(df['IBE6854'] <= 359.56, 359.56, df['IBE6854']))
# df['IBE2771'] = np.where(df['IBE2771'] >= 361.3, 361.3, np.where(df['IBE2771'] <= 361.3, 361.3, df['IBE2771']))
# df['IBE2190'] = np.where(df['IBE2190'] >= 204.41, 204.41, np.where(df['IBE2190'] <= 204.41, 204.41, df['IBE2190']))
# df['IBE9750'] = np.where(df['IBE9750'] >= 1568732.9749999999, 1568732.9749999999, np.where(df['IBE9750'] <= 177960.21500000008, 177960.21500000008, df['IBE9750']))
# df['IBE2189'] = np.where(df['IBE2189'] >= 310.89, 310.89, np.where(df['IBE2189'] <= 310.89, 310.89, df['IBE2189']))
# df['IBE2184'] = np.where(df['IBE2184'] >= 825.2, 825.2, np.where(df['IBE2184'] <= 825.2, 825.2, df['IBE2184']))
# df['IBE8705'] = np.where(df['IBE8705'] >= 743919.83, 743919.83, np.where(df['IBE8705'] <= 743919.83, 743919.83, df['IBE8705']))
# df['IBE8446'] = np.where(df['IBE8446'] >= 14885.0, 14885.0, np.where(df['IBE8446'] <= 3741.0, 3741.0, df['IBE8446']))
# df['IBE2759'] = np.where(df['IBE2759'] >= 290.65, 290.65, np.where(df['IBE2759'] <= 290.65, 290.65, df['IBE2759']))
# df['IBE6856'] = np.where(df['IBE6856'] >= 381.79, 381.79, np.where(df['IBE6856'] <= 381.79, 381.79, df['IBE6856']))
# df['IBE2765'] = np.where(df['IBE2765'] >= 457.83, 457.83, np.where(df['IBE2765'] <= 457.83, 457.83, df['IBE2765']))
# df['IBE8588'] = np.where(df['IBE8588'] >= 4808.225, 4808.225, np.where(df['IBE8588'] <= 375.8649999999998, 375.8649999999998, df['IBE8588']))
# df['IBE2188'] = np.where(df['IBE2188'] >= 270.54, 270.54, np.where(df['IBE2188'] <= 270.54, 270.54, df['IBE2188']))
# df['IBE2767'] = np.where(df['IBE2767'] >= 408.55, 408.55, np.where(df['IBE2767'] <= 408.55, 408.55, df['IBE2767']))
# df['IBE2169'] = np.where(df['IBE2169'] >= 302.06, 302.06, np.where(df['IBE2169'] <= 302.06, 302.06, df['IBE2169']))
# df['IBE8589'] = np.where(df['IBE8589'] >= 327807.25, 327807.25, np.where(df['IBE8589'] <= -182090.75, -182090.75, df['IBE8589']))
# df['IBE2773'] = np.where(df['IBE2773'] >= 305.47, 305.47, np.where(df['IBE2773'] <= 305.47, 305.47, df['IBE2773']))
# df['IBE6870'] = np.where(df['IBE6870'] >= 399.43, 399.43, np.where(df['IBE6870'] <= 399.43, 399.43, df['IBE6870']))
# df['IBE2755'] = np.where(df['IBE2755'] >= 471.91, 471.91, np.where(df['IBE2755'] <= 471.91, 471.91, df['IBE2755']))
# df['IBE2191'] = np.where(df['IBE2191'] >= 103.69, 103.69, np.where(df['IBE2191'] <= 103.69, 103.69, df['IBE2191']))
# df['IBE2768'] = np.where(df['IBE2768'] >= 496.68, 496.68, np.where(df['IBE2768'] <= 496.68, 496.68, df['IBE2768']))
# df['IBE6875'] = np.where(df['IBE6875'] >= 370.83, 370.83, np.where(df['IBE6875'] <= 370.83, 370.83, df['IBE6875']))
# df['IBE2171'] = np.where(df['IBE2171'] >= 1086.4499999999998, 1086.4499999999998, np.where(df['IBE2171'] <= -48.66999999999996, -48.66999999999996, df['IBE2171']))
# df['IBE2366'] = np.where(df['IBE2366'] >= 136.31, 136.31, np.where(df['IBE2366'] <= 136.31, 136.31, df['IBE2366']))
# df['IBE2181'] = np.where(df['IBE2181'] >= 427.65, 427.65, np.where(df['IBE2181'] <= 322.61, 322.61, df['IBE2181']))
# df['IBE2769'] = np.where(df['IBE2769'] >= 380.46, 380.46, np.where(df['IBE2769'] <= 380.46, 380.46, df['IBE2769']))
# df['IBE6813'] = np.where(df['IBE6813'] >= 7040.5, 7040.5, np.where(df['IBE6813'] <= -3571.5, -3571.5, df['IBE6813']))
# df['IBE6866'] = np.where(df['IBE6866'] >= 357.94, 357.94, np.where(df['IBE6866'] <= 357.94, 357.94, df['IBE6866']))
# df['IBE2761'] = np.where(df['IBE2761'] >= 329.25, 329.25, np.where(df['IBE2761'] <= 329.25, 329.25, df['IBE2761']))
# df['IBE6355'] = np.where(df['IBE6355'] >= 20186438.5, 20186438.5, np.where(df['IBE6355'] <= 19985602.5, 19985602.5, df['IBE6355']))
# df['IBE2175'] = np.where(df['IBE2175'] >= 354.33, 354.33, np.where(df['IBE2175'] <= 354.33, 354.33, df['IBE2175']))
# df['IBE2751'] = np.where(df['IBE2751'] >= 265.28, 265.28, np.where(df['IBE2751'] <= 265.28, 265.28, df['IBE2751']))
# df['IBE6357'] = np.where(df['IBE6357'] >= 20185497.5, 20185497.5, np.where(df['IBE6357'] <= 19985045.5, 19985045.5, df['IBE6357']))
# df['IBE2368'] = np.where(df['IBE2368'] >= 2572.1000000000004, 2572.1000000000004, np.where(df['IBE2368'] <= -1200.8600000000001, -1200.8600000000001, df['IBE2368']))
# df['IBE2774'] = np.where(df['IBE2774'] >= 335.18, 335.18, np.where(df['IBE2774'] <= 335.18, 335.18, df['IBE2774']))
# df['IBE6869'] = np.where(df['IBE6869'] >= 395.02, 395.02, np.where(df['IBE6869'] <= 395.02, 395.02, df['IBE6869']))
# df['IBE2187'] = np.where(df['IBE2187'] >= 190.5, 190.5, np.where(df['IBE2187'] <= 190.5, 190.5, df['IBE2187']))
# df['IBE6708'] = np.where(df['IBE6708'] >= 3003.575, 3003.575, np.where(df['IBE6708'] <= -1573.345, -1573.345, df['IBE6708']))
# df['IBE2772'] = np.where(df['IBE2772'] >= 229.52, 229.52, np.where(df['IBE2772'] <= 229.52, 229.52, df['IBE2772']))
# df['IBE2764'] = np.where(df['IBE2764'] >= 329.09, 329.09, np.where(df['IBE2764'] <= 329.09, 329.09, df['IBE2764']))
# df['IBE8558'] = np.where(df['IBE8558'] >= 101.0, 101.0, np.where(df['IBE8558'] <= -11.0, -11.0, df['IBE8558']))
# df['IBE2167'] = np.where(df['IBE2167'] >= 1990.475, 1990.475, np.where(df['IBE2167'] <= -840.685, -840.685, df['IBE2167']))
# df['IBE2174'] = np.where(df['IBE2174'] >= 1093.1, 1093.1, np.where(df['IBE2174'] <= -295.86, -295.86, df['IBE2174']))
# df['IBE6686'] = np.where(df['IBE6686'] >= 4906.5, 4906.5, np.where(df['IBE6686'] <= -2497.5, -2497.5, df['IBE6686']))
# df['IBE2754'] = np.where(df['IBE2754'] >= 268.92, 268.92, np.where(df['IBE2754'] <= 268.92, 268.92, df['IBE2754']))
# df['IBE8840'] = np.where(df['IBE8840'] >= 29115.89, 29115.89, np.where(df['IBE8840'] <= 29115.89, 29115.89, df['IBE8840']))
# df['IBE6356'] = np.where(df['IBE6356'] >= 20195520.0, 20195520.0, np.where(df['IBE6356'] <= 20156304.0, 20156304.0, df['IBE6356']))
# df['IBE2766'] = np.where(df['IBE2766'] >= 286.26, 286.26, np.where(df['IBE2766'] <= 286.26, 286.26, df['IBE2766']))
# df['IBE6533'] = np.where(df['IBE6533'] >= 20253596.5, 20253596.5, np.where(df['IBE6533'] <= 20137648.5, 20137648.5, df['IBE6533']))
# df['IBE6863'] = np.where(df['IBE6863'] >= 266.97, 266.97, np.where(df['IBE6863'] <= 266.97, 266.97, df['IBE6863']))
# df['IBE6121'] = np.where(df['IBE6121'] >= 1153.9, 1153.9, np.where(df['IBE6121'] <= -522.74, -522.74, df['IBE6121']))
# df['IBE6132'] = np.where(df['IBE6132'] >= 1014.0, 1014.0, np.where(df['IBE6132'] <= -437.20000000000005, -437.20000000000005, df['IBE6132']))
# df['IBE6128'] = np.where(df['IBE6128'] >= 1177.6000000000001, 1177.6000000000001, np.where(df['IBE6128'] <= -532.1600000000001, -532.1600000000001, df['IBE6128']))
# df['IBE8579'] = np.where(df['IBE8579'] >= 200912.49, 200912.49, np.where(df['IBE8579'] <= 200912.49, 200912.49, df['IBE8579']))
# df['IBE2186'] = np.where(df['IBE2186'] >= 104.48, 104.48, np.where(df['IBE2186'] <= 104.48, 104.48, df['IBE2186']))
# df['IBE6532'] = np.where(df['IBE6532'] >= 20240017.5, 20240017.5, np.where(df['IBE6532'] <= 20160829.5, 20160829.5, df['IBE6532']))
# df['IBE6858'] = np.where(df['IBE6858'] >= 353.22499999999997, 353.22499999999997, np.where(df['IBE6858'] <= 109.66500000000002, 109.66500000000002, df['IBE6858']))
# df['IBE6131'] = np.where(df['IBE6131'] >= 1201.3, 1201.3, np.where(df['IBE6131'] <= -552.78, -552.78, df['IBE6131']))
# df['IBE6129'] = np.where(df['IBE6129'] >= 1232.45, 1232.45, np.where(df['IBE6129'] <= -563.47, -563.47, df['IBE6129']))
# df['IBE6127'] = np.where(df['IBE6127'] >= 1078.6499999999999, 1078.6499999999999, np.where(df['IBE6127'] <= -479.18999999999994, -479.18999999999994, df['IBE6127']))
# df['IBE6130'] = np.where(df['IBE6130'] >= 1248.1, 1248.1, np.where(df['IBE6130'] <= -556.86, -556.86, df['IBE6130']))
# df['IBE6122'] = np.where(df['IBE6122'] >= 994.3500000000001, 994.3500000000001, np.where(df['IBE6122'] <= -431.81000000000006, -431.81000000000006, df['IBE6122']))
# df['IBE6124'] = np.where(df['IBE6124'] >= 979.4, 979.4, np.where(df['IBE6124'] <= -427.64, -427.64, df['IBE6124']))
# df['IBE6123'] = np.where(df['IBE6123'] >= 1447.5499999999997, 1447.5499999999997, np.where(df['IBE6123'] <= -670.1299999999999, -670.1299999999999, df['IBE6123']))
# df['IBE6125'] = np.where(df['IBE6125'] >= 1013.4, 1013.4, np.where(df['IBE6125'] <= -449.64, -449.64, df['IBE6125']))
# df['IBE6126'] = np.where(df['IBE6126'] >= 990.1999999999999, 990.1999999999999, np.where(df['IBE6126'] <= -437.31999999999994, -437.31999999999994, df['IBE6126']))
# df['IBE6865'] = np.where(df['IBE6865'] >= 401.79999999999995, 401.79999999999995, np.where(df['IBE6865'] <= 96.52000000000001, 96.52000000000001, df['IBE6865']))
# df['IBE6535'] = np.where(df['IBE6535'] >= 20228286.455, 20228286.455, np.where(df['IBE6535'] <= 20180890.575000003, 20180890.575000003, df['IBE6535']))
# df['IBE2752'] = np.where(df['IBE2752'] >= 338.925, 338.925, np.where(df['IBE2752'] <= 57.44499999999999, 57.44499999999999, df['IBE2752']))
# df['IBE8643'] = np.where(df['IBE8643'] >= 202596.5, 202596.5, np.where(df['IBE8643'] <= 199408.5, 199408.5, df['IBE8643']))
# df['IBE2756'] = np.where(df['IBE2756'] >= 441.5, 441.5, np.where(df['IBE2756'] <= -34.5, -34.5, df['IBE2756']))
# df['IBE6161'] = np.where(df['IBE6161'] >= 628.5, 628.5, np.where(df['IBE6161'] <= -239.5, -239.5, df['IBE6161']))
# df['IBE6163'] = np.where(df['IBE6163'] >= 392.5, 392.5, np.where(df['IBE6163'] <= -83.5, -83.5, df['IBE6163']))
# df['IBE6685'] = np.where(df['IBE6685'] >= 629.5, 629.5, np.where(df['IBE6685'] <= -254.5, -254.5, df['IBE6685']))
# df['IBE8704'] = np.where(df['IBE8704'] >= 61.93, 61.93, np.where(df['IBE8704'] <= 61.93, 61.93, df['IBE8704']))
# df['IBE9057'] = np.where(df['IBE9057'] >= 20190157.83, 20190157.83, np.where(df['IBE9057'] <= 20190157.83, 20190157.83, df['IBE9057']))
# df['IBE6853'] = np.where(df['IBE6853'] >= 418.0, 418.0, np.where(df['IBE6853'] <= -94.0, -94.0, df['IBE6853']))
# df['IBE6840'] = np.where(df['IBE6840'] >= 324.5, 324.5, np.where(df['IBE6840'] <= 8.5, 8.5, df['IBE6840']))
# df['IBE6872'] = np.where(df['IBE6872'] >= 198.775, 198.775, np.where(df['IBE6872'] <= -66.465, -66.465, df['IBE6872']))
# df['IBE6707'] = np.where(df['IBE6707'] >= 445.25, 445.25, np.where(df['IBE6707'] <= -163.14999999999998, -163.14999999999998, df['IBE6707']))
# df['IBE6843'] = np.where(df['IBE6843'] >= 320.0, 320.0, np.where(df['IBE6843'] <= -128.0, -128.0, df['IBE6843']))
# df['IBE6162'] = np.where(df['IBE6162'] >= 311.5, 311.5, np.where(df['IBE6162'] <= -132.5, -132.5, df['IBE6162']))
# df['IBE8559'] = np.where(df['IBE8559'] >= 39.735, 39.735, np.where(df['IBE8559'] <= 29.774999999999995, 29.774999999999995, df['IBE8559']))
# df['IBE8580'] = np.where(df['IBE8580'] >= 2009.06, 2009.06, np.where(df['IBE8580'] <= 2009.06, 2009.06, df['IBE8580']))
# df['IBE2157'] = np.where(df['IBE2157'] >= 2.93, 2.93, np.where(df['IBE2157'] <= 2.93, 2.93, df['IBE2157']))
# df['IBE9751'] = np.where(df['IBE9751'] >= 11.86, 11.86, np.where(df['IBE9751'] <= 11.86, 11.86, df['IBE9751']))
# df['IBE6841'] = np.where(df['IBE6841'] >= 347.0, 347.0, np.where(df['IBE6841'] <= -37.0, -37.0, df['IBE6841']))
# df['IBE6844'] = np.where(df['IBE6844'] >= 280.0, 280.0, np.where(df['IBE6844'] <= -120.0, -120.0, df['IBE6844']))
# df['IBE2097'] = np.where(df['IBE2097'] >= 4.89, 4.89, np.where(df['IBE2097'] <= 4.89, 4.89, df['IBE2097']))
# df['IBE8691_01'] = np.where(df['IBE8691_01'] >= 1976.43, 1976.43, np.where(df['IBE8691_01'] <= 1976.43, 1976.43, df['IBE8691_01']))
# df['IBE6164'] = np.where(df['IBE6164'] >= 283.5, 283.5, np.where(df['IBE6164'] <= -120.5, -120.5, df['IBE6164']))
# df['IBE6842'] = np.where(df['IBE6842'] >= 346.5, 346.5, np.where(df['IBE6842'] <= -41.5, -41.5, df['IBE6842']))
# df['IBE9047'] = np.where(df['IBE9047'] >= 20199101.025000002, 20199101.025000002, np.where(df['IBE9047'] <= 20185664.185, 20185664.185, df['IBE9047']))
# df['IBE8562_01'] = np.where(df['IBE8562_01'] >= 2013.27, 2013.27, np.where(df['IBE8562_01'] <= 2013.27, 2013.27, df['IBE8562_01']))
# df['IBE8607'] = np.where(df['IBE8607'] >= 33.0, 33.0, np.where(df['IBE8607'] <= -15.0, -15.0, df['IBE8607']))
# df['IBE6845'] = np.where(df['IBE6845'] >= 198.0, 198.0, np.where(df['IBE6845'] <= -82.0, -82.0, df['IBE6845']))
# df['IBE8592'] = np.where(df['IBE8592'] >= 1969.0, 1969.0, np.where(df['IBE8592'] <= 1945.0, 1945.0, df['IBE8592']))
# df['IBE6106'] = np.where(df['IBE6106'] >= 2.71, 2.71, np.where(df['IBE6106'] <= 2.71, 2.71, df['IBE6106']))
# df['IBE8582'] = np.where(df['IBE8582'] >= 9.2, 9.2, np.where(df['IBE8582'] <= 9.2, 9.2, df['IBE8582']))
# df['IBE7607_01'] = np.where(df['IBE7607_01'] >= 34.5, 34.5, np.where(df['IBE7607_01'] <= -17.5, -17.5, df['IBE7607_01']))
# df['IBE2403_01'] = np.where(df['IBE2403_01'] >= 22.5, 22.5, np.where(df['IBE2403_01'] <= -5.5, -5.5, df['IBE2403_01']))
# df['IBE8644'] = np.where(df['IBE8644'] >= 2026.0, 2026.0, np.where(df['IBE8644'] <= 1994.0, 1994.0, df['IBE8644']))
# df['IBE2148'] = np.where(df['IBE2148'] >= 3.15, 3.15, np.where(df['IBE2148'] <= 3.15, 3.15, df['IBE2148']))
# df['IBE8434_01'] = np.where(df['IBE8434_01'] >= 2013.84, 2013.84, np.where(df['IBE8434_01'] <= 2013.84, 2013.84, df['IBE8434_01']))
# df['IBE9051'] = np.where(df['IBE9051'] >= 39.43, 39.43, np.where(df['IBE9051'] <= 39.43, 39.43, df['IBE9051']))
# df['TP000105'] = np.where(df['TP000105'] >= 152.0, 152.0, np.where(df['TP000105'] <= -8.0, -8.0, df['TP000105']))
# df['IBE2149'] = np.where(df['IBE2149'] >= 2.06, 2.06, np.where(df['IBE2149'] <= 2.06, 2.06, df['IBE2149']))
# df['IBE9160_01'] = np.where(df['IBE9160_01'] >= 20222891.25, 20222891.25, np.where(df['IBE9160_01'] <= 20163181.25, 20163181.25, df['IBE9160_01']))
# df['IBE9159_01'] = np.where(df['IBE9159_01'] >= 20218208.625, 20218208.625, np.where(df['IBE9159_01'] <= 20171785.625, 20171785.625, df['IBE9159_01']))
# df['IBE9158_01'] = np.where(df['IBE9158_01'] >= 20214371.105, 20214371.105, np.where(df['IBE9158_01'] <= 20178714.825, 20178714.825, df['IBE9158_01']))
# df['IBE6720'] = np.where(df['IBE6720'] >= 6.4, 6.4, np.where(df['IBE6720'] <= -2.24, -2.24, df['IBE6720']))
# df['IBE8623_01'] = np.where(df['IBE8623_01'] >= 2015.5, 2015.5, np.where(df['IBE8623_01'] <= 1923.5, 1923.5, df['IBE8623_01']))
# df['IBE8618_01'] = np.where(df['IBE8618_01'] >= 1969.0, 1969.0, np.where(df['IBE8618_01'] <= 1961.0, 1961.0, df['IBE8618_01']))
# df['IBE8444'] = np.where(df['IBE8444'] >= 34.7, 34.7, np.where(df['IBE8444'] <= 17.58, 17.58, df['IBE8444']))
# df['IBE2161'] = np.where(df['IBE2161'] >= 22.475, 22.475, np.where(df['IBE2161'] <= -7.085000000000001, -7.085000000000001, df['IBE2161']))
# df['IBE9157_01'] = np.where(df['IBE9157_01'] >= 20231609.244999997, 20231609.244999997, np.where(df['IBE9157_01'] <= 20174517.925000004, 20174517.925000004, df['IBE9157_01']))
# df['IBE1273_01'] = np.where(df['IBE1273_01'] >= 22.5, 22.5, np.where(df['IBE1273_01'] <= -5.5, -5.5, df['IBE1273_01']))
# df['IBE6814'] = np.where(df['IBE6814'] >= 64.5, 64.5, np.where(df['IBE6814'] <= -27.5, -27.5, df['IBE6814']))
# df['IBE9152'] = np.where(df['IBE9152'] >= 20227368.28, 20227368.28, np.where(df['IBE9152'] <= 20182386.200000003, 20182386.200000003, df['IBE9152']))
# df['IBE9156_01'] = np.where(df['IBE9156_01'] >= 20227368.28, 20227368.28, np.where(df['IBE9156_01'] <= 20182386.200000003, 20182386.200000003, df['IBE9156_01']))
# df['IBE9041'] = np.where(df['IBE9041'] >= 38.91, 38.91, np.where(df['IBE9041'] <= 38.91, 38.91, df['IBE9041']))
# df['IBE2082'] = np.where(df['IBE2082'] >= 3.31, 3.31, np.where(df['IBE2082'] <= 3.31, 3.31, df['IBE2082']))
# df['IBE8626'] = np.where(df['IBE8626'] >= 95.0, 95.0, np.where(df['IBE8626'] <= 7.0, 7.0, df['IBE8626']))
# df['IBE6718'] = np.where(df['IBE6718'] >= 14.850000000000001, 14.850000000000001, np.where(df['IBE6718'] <= -7.3100000000000005, -7.3100000000000005, df['IBE6718']))
# df['AP008728'] = np.where(df['AP008728'] >= 11.0, 11.0, np.where(df['AP008728'] <= -5.0, -5.0, df['AP008728']))
# df['PX001270_01'] = np.where(df['PX001270_01'] >= 19.5, 19.5, np.where(df['PX001270_01'] <= -8.5, -8.5, df['PX001270_01']))
# df['TP000620'] = np.where(df['TP000620'] >= 110.5, 110.5, np.where(df['TP000620'] <= -45.5, -45.5, df['TP000620']))
# df['AP000903'] = np.where(df['AP000903'] >= 17.0, 17.0, np.where(df['AP000903'] <= -7.0, -7.0, df['AP000903']))
# df['IBE8682'] = np.where(df['IBE8682'] >= 43.91, 43.91, np.where(df['IBE8682'] <= 43.91, 43.91, df['IBE8682']))
# df['IBE6105'] = np.where(df['IBE6105'] >= 2.32, 2.32, np.where(df['IBE6105'] <= 2.32, 2.32, df['IBE6105']))
# df['IBE8442'] = np.where(df['IBE8442'] >= 7.8, 7.8, np.where(df['IBE8442'] <= 7.8, 7.8, df['IBE8442']))
# df['AP003595'] = np.where(df['AP003595'] >= 13.5, 13.5, np.where(df['AP003595'] <= -6.5, -6.5, df['AP003595']))
# df['TP000159'] = np.where(df['TP000159'] >= 152.5, 152.5, np.where(df['TP000159'] <= -19.5, -19.5, df['TP000159']))
# df['IBE8611_01'] = np.where(df['IBE8611_01'] >= 2013.0, 2013.0, np.where(df['IBE8611_01'] <= 1925.0, 1925.0, df['IBE8611_01']))
# df['IBE2147'] = np.where(df['IBE2147'] >= 2.46, 2.46, np.where(df['IBE2147'] <= 2.46, 2.46, df['IBE2147']))
# df['IBE7616_01'] = np.where(df['IBE7616_01'] >= 100.0, 100.0, np.where(df['IBE7616_01'] <= 4.0, 4.0, df['IBE7616_01']))
# df['IBE7110'] = np.where(df['IBE7110'] >= 22.0, 22.0, np.where(df['IBE7110'] <= -10.0, -10.0, df['IBE7110']))
# df['IBE6722'] = np.where(df['IBE6722'] >= 6.300000000000001, 6.300000000000001, np.where(df['IBE6722'] <= -2.18, -2.18, df['IBE6722']))
# df['IBE6609'] = np.where(df['IBE6609'] >= 30.5, 30.5, np.where(df['IBE6609'] <= -13.5, -13.5, df['IBE6609']))
# df['AP003594'] = np.where(df['AP003594'] >= 13.5, 13.5, np.where(df['AP003594'] <= -6.5, -6.5, df['AP003594']))
# df['IBE8617'] = np.where(df['IBE8617'] >= 59.0, 59.0, np.where(df['IBE8617'] <= 51.0, 51.0, df['IBE8617']))
# df['AP001154'] = np.where(df['AP001154'] >= 20.5, 20.5, np.where(df['AP001154'] <= -7.5, -7.5, df['AP001154']))
# df['IBE6721'] = np.where(df['IBE6721'] >= 2.175, 2.175, np.where(df['IBE6721'] <= 1.8950000000000002, 1.8950000000000002, df['IBE6721']))
# df['AP001181'] = np.where(df['AP001181'] >= 8.5, 8.5, np.where(df['AP001181'] <= -3.5, -3.5, df['AP001181']))
# df['IBE2153'] = np.where(df['IBE2153'] >= 1.88, 1.88, np.where(df['IBE2153'] <= 1.88, 1.88, df['IBE2153']))
# df['IBE9350'] = np.where(df['IBE9350'] >= 19.5, 19.5, np.where(df['IBE9350'] <= -8.5, -8.5, df['IBE9350']))
# df['IBE8616'] = np.where(df['IBE8616'] >= 95.0, 95.0, np.where(df['IBE8616'] <= 7.0, 7.0, df['IBE8616']))
# df['AP003591'] = np.where(df['AP003591'] >= 15.0, 15.0, np.where(df['AP003591'] <= -1.0, -1.0, df['AP003591']))
# df['AP006251_01'] = np.where(df['AP006251_01'] >= 123.5, 123.5, np.where(df['AP006251_01'] <= 47.5, 47.5, df['AP006251_01']))
# df['AP003592'] = np.where(df['AP003592'] >= 13.5, 13.5, np.where(df['AP003592'] <= 1.5, 1.5, df['AP003592']))
# df['TP000559'] = np.where(df['TP000559'] >= 71.0, 71.0, np.where(df['TP000559'] <= -33.0, -33.0, df['TP000559']))
# df['IBE8819_01'] = np.where(df['IBE8819_01'] >= 2014.54, 2014.54, np.where(df['IBE8819_01'] <= 2014.54, 2014.54, df['IBE8819_01']))
# df['AP008729'] = np.where(df['AP008729'] >= 6.0, 6.0, np.where(df['AP008729'] <= -2.0, -2.0, df['AP008729']))
# df['AP008717'] = np.where(df['AP008717'] >= 8.5, 8.5, np.where(df['AP008717'] <= -3.5, -3.5, df['AP008717']))
# df['IBE6603'] = np.where(df['IBE6603'] >= 6.225, 6.225, np.where(df['IBE6603'] <= -0.5350000000000001, -0.5350000000000001, df['IBE6603']))
# df['IBE2145'] = np.where(df['IBE2145'] >= 2.27, 2.27, np.where(df['IBE2145'] <= 2.27, 2.27, df['IBE2145']))
# df['IBE2144'] = np.where(df['IBE2144'] >= 1.73, 1.73, np.where(df['IBE2144'] <= 1.73, 1.73, df['IBE2144']))
# df['AP003587'] = np.where(df['AP003587'] >= 13.0, 13.0, np.where(df['AP003587'] <= -3.0, -3.0, df['AP003587']))
# df['IBE9358'] = np.where(df['IBE9358'] >= 11.0, 11.0, np.where(df['IBE9358'] <= -5.0, -5.0, df['IBE9358']))
# df['AP006249_01'] = np.where(df['AP006249_01'] >= 9.0, 9.0, np.where(df['AP006249_01'] <= 1.0, 1.0, df['AP006249_01']))
# df['IBE8560'] = np.where(df['IBE8560'] >= 8.26, 8.26, np.where(df['IBE8560'] <= 8.26, 8.26, df['IBE8560']))
# df['IBE6697'] = np.where(df['IBE6697'] >= 1.82, 1.82, np.where(df['IBE6697'] <= 1.82, 1.82, df['IBE6697']))
# df['IBE9050'] = np.where(df['IBE9050'] >= 40.47, 40.47, np.where(df['IBE9050'] <= 40.47, 40.47, df['IBE9050']))
# df['IBE9040'] = np.where(df['IBE9040'] >= 45.050000000000004, 45.050000000000004, np.where(df['IBE9040'] <= 35.37, 35.37, df['IBE9040']))
# df['TP000550'] = np.where(df['TP000550'] >= 72.5, 72.5, np.where(df['TP000550'] <= -35.5, -35.5, df['TP000550']))
# df['IBE4000'] = np.where(df['IBE4000'] >= 16.5, 16.5, np.where(df['IBE4000'] <= -3.5, -3.5, df['IBE4000']))
# df['AP003446'] = np.where(df['AP003446'] >= 12.0, 12.0, np.where(df['AP003446'] <= -4.0, -4.0, df['AP003446']))
# df['IBE7629_01'] = np.where(df['IBE7629_01'] >= 7.0, 7.0, np.where(df['IBE7629_01'] <= -1.0, -1.0, df['IBE7629_01']))
# df['IBE6696'] = np.where(df['IBE6696'] >= 28.0, 28.0, np.where(df['IBE6696'] <= -12.0, -12.0, df['IBE6696']))
# df['IBE8629'] = np.where(df['IBE8629'] >= 7.0, 7.0, np.where(df['IBE8629'] <= -1.0, -1.0, df['IBE8629']))
# df['TP000546'] = np.where(df['TP000546'] >= 77.0, 77.0, np.where(df['TP000546'] <= -35.0, -35.0, df['TP000546']))
# df['IBE2164'] = np.where(df['IBE2164'] >= 1.76, 1.76, np.where(df['IBE2164'] <= 1.76, 1.76, df['IBE2164']))
# df['TP000158'] = np.where(df['TP000158'] >= 101.0, 101.0, np.where(df['TP000158'] <= -43.0, -43.0, df['TP000158']))
# df['IBE9351'] = np.where(df['IBE9351'] >= 25.0, 25.0, np.where(df['IBE9351'] <= 9.0, 9.0, df['IBE9351']))
# df['IBE2094'] = np.where(df['IBE2094'] >= 3.61, 3.61, np.where(df['IBE2094'] <= 3.61, 3.61, df['IBE2094']))
# df['IBE6608'] = np.where(df['IBE6608'] >= 5.800000000000001, 5.800000000000001, np.where(df['IBE6608'] <= -0.28000000000000025, -0.28000000000000025, df['IBE6608']))
# df['IBE7628_01'] = np.where(df['IBE7628_01'] >= 6.0, 6.0, np.where(df['IBE7628_01'] <= -2.0, -2.0, df['IBE7628_01']))
# df['IBE2154'] = np.where(df['IBE2154'] >= 2.12, 2.12, np.where(df['IBE2154'] <= 2.12, 2.12, df['IBE2154']))
# df['IBE8614'] = np.where(df['IBE8614'] >= 20215.5, 20215.5, np.where(df['IBE8614'] <= 20211.5, 20211.5, df['IBE8614']))
# df['IBE8628'] = np.where(df['IBE8628'] >= 6.0, 6.0, np.where(df['IBE8628'] <= -2.0, -2.0, df['IBE8628']))
# df['IBE4100'] = np.where(df['IBE4100'] >= 14.5, 14.5, np.where(df['IBE4100'] <= 2.5, 2.5, df['IBE4100']))
# df['IBE2156'] = np.where(df['IBE2156'] >= 2.01, 2.01, np.where(df['IBE2156'] <= 2.01, 2.01, df['IBE2156']))
# df['IBE2084'] = np.where(df['IBE2084'] >= 5.025, 5.025, np.where(df['IBE2084'] <= 1.785, 1.785, df['IBE2084']))
# df['AP003447'] = np.where(df['AP003447'] >= 8.5, 8.5, np.where(df['AP003447'] <= -3.5, -3.5, df['AP003447']))
# df['AP001238'] = np.where(df['AP001238'] >= 17.0, 17.0, np.where(df['AP001238'] <= -7.0, -7.0, df['AP001238']))
# df['IBE2146'] = np.where(df['IBE2146'] >= 1.97, 1.97, np.where(df['IBE2146'] <= 1.97, 1.97, df['IBE2146']))
# df['IBE2080'] = np.where(df['IBE2080'] >= 11.399999999999999, 11.399999999999999, np.where(df['IBE2080'] <= -3.6399999999999997, -3.6399999999999997, df['IBE2080']))
# df['IBE8597'] = np.where(df['IBE8597'] >= 3.77, 3.77, np.where(df['IBE8597'] <= 3.77, 3.77, df['IBE8597']))
# df['IBE6723'] = np.where(df['IBE6723'] >= 1.55, 1.55, np.where(df['IBE6723'] <= 1.55, 1.55, df['IBE6723']))
# df['IBE8562_02'] = np.where(df['IBE8562_02'] >= 6.36, 6.36, np.where(df['IBE8562_02'] <= 6.36, 6.36, df['IBE8562_02']))
# df['IBE6724'] = np.where(df['IBE6724'] >= 5.775, 5.775, np.where(df['IBE6724'] <= -1.8650000000000002, -1.8650000000000002, df['IBE6724']))
# df['IBE6118'] = np.where(df['IBE6118'] >= 6.0, 6.0, np.where(df['IBE6118'] <= -2.0, -2.0, df['IBE6118']))
# df['IBE8463'] = np.where(df['IBE8463'] >= 5.625, 5.625, np.where(df['IBE8463'] <= -0.17500000000000027, -0.17500000000000027, df['IBE8463']))
# df['AP006250_01'] = np.where(df['AP006250_01'] >= 9.5, 9.5, np.where(df['AP006250_01'] <= -2.5, -2.5, df['AP006250_01']))
# df['IBE2159'] = np.where(df['IBE2159'] >= 2.0, 2.0, np.where(df['IBE2159'] <= 2.0, 2.0, df['IBE2159']))
# df['IBE2088'] = np.where(df['IBE2088'] >= 2.21, 2.21, np.where(df['IBE2088'] <= 2.21, 2.21, df['IBE2088']))
# df['IBE6700'] = np.where(df['IBE6700'] >= 11.099999999999998, 11.099999999999998, np.where(df['IBE6700'] <= -3.459999999999999, -3.459999999999999, df['IBE6700']))
# df['IBE6719'] = np.where(df['IBE6719'] >= 1.6, 1.6, np.where(df['IBE6719'] <= 1.6, 1.6, df['IBE6719']))
# df['IBE6604'] = np.where(df['IBE6604'] >= 5.1499999999999995, 5.1499999999999995, np.where(df['IBE6604'] <= 0.11000000000000032, 0.11000000000000032, df['IBE6604']))
# df['AP008727'] = np.where(df['AP008727'] >= 6.0, 6.0, np.where(df['AP008727'] <= -2.0, -2.0, df['AP008727']))
# df['IBE2087'] = np.where(df['IBE2087'] >= 7.949999999999999, 7.949999999999999, np.where(df['IBE2087'] <= -1.5699999999999998, -1.5699999999999998, df['IBE2087']))
# df['IBE6702'] = np.where(df['IBE6702'] >= 12.674999999999999, 12.674999999999999, np.where(df['IBE6702'] <= -4.404999999999999, -4.404999999999999, df['IBE6702']))
# df['IBE6114'] = np.where(df['IBE6114'] >= 6.0, 6.0, np.where(df['IBE6114'] <= -2.0, -2.0, df['IBE6114']))
# df['IBE6116'] = np.where(df['IBE6116'] >= 6.0, 6.0, np.where(df['IBE6116'] <= -2.0, -2.0, df['IBE6116']))
# df['IBE6119'] = np.where(df['IBE6119'] >= 5.15, 5.15, np.where(df['IBE6119'] <= -1.4900000000000002, -1.4900000000000002, df['IBE6119']))
# df['IBE6605'] = np.where(df['IBE6605'] >= 6.174999999999999, 6.174999999999999, np.where(df['IBE6605'] <= -2.1049999999999995, -2.1049999999999995, df['IBE6605']))
# df['IBE9052'] = np.where(df['IBE9052'] >= 2009.25, 2009.25, np.where(df['IBE9052'] <= 2009.25, 2009.25, df['IBE9052']))
# df['AP003593'] = np.where(df['AP003593'] >= 13.0, 13.0, np.where(df['AP003593'] <= 5.0, 5.0, df['AP003593']))
# df['IBE6111'] = np.where(df['IBE6111'] >= 5.025, 5.025, np.where(df['IBE6111'] <= -1.415, -1.415, df['IBE6111']))
# df['IBE6698'] = np.where(df['IBE6698'] >= 7.324999999999999, 7.324999999999999, np.where(df['IBE6698'] <= -1.1949999999999998, -1.1949999999999998, df['IBE6698']))
# df['IBE6117'] = np.where(df['IBE6117'] >= 4.875, 4.875, np.where(df['IBE6117'] <= 0.27500000000000013, 0.27500000000000013, df['IBE6117']))
# df['IBE6108'] = np.where(df['IBE6108'] >= 6.0, 6.0, np.where(df['IBE6108'] <= -2.0, -2.0, df['IBE6108']))
# df['IBE6611'] = np.where(df['IBE6611'] >= 6.200000000000001, 6.200000000000001, np.where(df['IBE6611'] <= -0.5200000000000005, -0.5200000000000005, df['IBE6611']))
# df['AP002781'] = np.where(df['AP002781'] >= 8.5, 8.5, np.where(df['AP002781'] <= -3.5, -3.5, df['AP002781']))
# df['AP003588'] = np.where(df['AP003588'] >= 8.5, 8.5, np.where(df['AP003588'] <= -3.5, -3.5, df['AP003588']))
# df['IBE2800'] = np.where(df['IBE2800'] >= 4.5, 4.5, np.where(df['IBE2800'] <= 0.5, 0.5, df['IBE2800']))
# df['IBE6112'] = np.where(df['IBE6112'] >= 6.0, 6.0, np.where(df['IBE6112'] <= -2.0, -2.0, df['IBE6112']))
# df['AP001241'] = np.where(df['AP001241'] >= 23.0, 23.0, np.where(df['AP001241'] <= -9.0, -9.0, df['AP001241']))
# df['IBE6699'] = np.where(df['IBE6699'] >= 2.6000000000000005, 2.6000000000000005, np.where(df['IBE6699'] <= 1.6399999999999997, 1.6399999999999997, df['IBE6699']))
# df['IBE8839_01'] = np.where(df['IBE8839_01'] >= 2022.6950000000002, 2022.6950000000002, np.where(df['IBE8839_01'] <= 2018.1749999999997, 2018.1749999999997, df['IBE8839_01']))
# df['IBE6701'] = np.where(df['IBE6701'] >= 1.74, 1.74, np.where(df['IBE6701'] <= 1.74, 1.74, df['IBE6701']))
# df['AP005423'] = np.where(df['AP005423'] >= 13.5, 13.5, np.where(df['AP005423'] <= -6.5, -6.5, df['AP005423']))
# df['AP001216'] = np.where(df['AP001216'] >= 31.5, 31.5, np.where(df['AP001216'] <= -4.5, -4.5, df['AP001216']))
# df['IBE8819_02'] = np.where(df['IBE8819_02'] >= 6.62, 6.62, np.where(df['IBE8819_02'] <= 6.62, 6.62, df['IBE8819_02']))
# df['IBE8816'] = np.where(df['IBE8816'] >= 11.5, 11.5, np.where(df['IBE8816'] <= -0.5, -0.5, df['IBE8816']))
# df['AP008718'] = np.where(df['AP008718'] >= 17.0, 17.0, np.where(df['AP008718'] <= -7.0, -7.0, df['AP008718']))
# df['IBE7602_01'] = np.where(df['IBE7602_01'] >= 2.5, 2.5, np.where(df['IBE7602_01'] <= -1.5, -1.5, df['IBE7602_01']))
# df['AP000920'] = np.where(df['AP000920'] >= 31.5, 31.5, np.where(df['AP000920'] <= -12.5, -12.5, df['AP000920']))
# df['AP002778'] = np.where(df['AP002778'] >= 13.0, 13.0, np.where(df['AP002778'] <= -3.0, -3.0, df['AP002778']))
# df['IBE6109'] = np.where(df['IBE6109'] >= 4.9, 4.9, np.where(df['IBE6109'] <= -1.3399999999999999, -1.3399999999999999, df['IBE6109']))
# df['AP005385'] = np.where(df['AP005385'] >= 33.5, 33.5, np.where(df['AP005385'] <= -2.5, -2.5, df['AP005385']))
# df['IBE8590_01'] = np.where(df['IBE8590_01'] >= 6.49, 6.49, np.where(df['IBE8590_01'] <= 6.49, 6.49, df['IBE8590_01']))
# df['IBE8434_02'] = np.where(df['IBE8434_02'] >= 6.49, 6.49, np.where(df['IBE8434_02'] <= 6.49, 6.49, df['IBE8434_02']))
# df['AP003590'] = np.where(df['AP003590'] >= 14.5, 14.5, np.where(df['AP003590'] <= 2.5, 2.5, df['AP003590']))
# df['IBE8652'] = np.where(df['IBE8652'] >= 3.5, 3.5, np.where(df['IBE8652'] <= -0.5, -0.5, df['IBE8652']))
# df['IBE6113'] = np.where(df['IBE6113'] >= 6.0, 6.0, np.where(df['IBE6113'] <= -2.0, -2.0, df['IBE6113']))
# df['AP000953'] = np.where(df['AP000953'] >= 31.0, 31.0, np.where(df['AP000953'] <= -1.0, -1.0, df['AP000953']))
# df['IBE6115'] = np.where(df['IBE6115'] >= 6.0, 6.0, np.where(df['IBE6115'] <= -2.0, -2.0, df['IBE6115']))
# df['IBE6110'] = np.where(df['IBE6110'] >= 7.0, 7.0, np.where(df['IBE6110'] <= -1.0, -1.0, df['IBE6110']))
# df['AP006332'] = np.where(df['AP006332'] >= 30.0, 30.0, np.where(df['AP006332'] <= -10.0, -10.0, df['AP006332']))
# df['IBE8691_02'] = np.where(df['IBE8691_02'] >= 6.38, 6.38, np.where(df['IBE8691_02'] <= 6.38, 6.38, df['IBE8691_02']))
# df['AP002897'] = np.where(df['AP002897'] >= 11.0, 11.0, np.where(df['AP002897'] <= -5.0, -5.0, df['AP002897']))
# df['IBE8641'] = np.where(df['IBE8641'] >= 10.5, 10.5, np.where(df['IBE8641'] <= 6.5, 6.5, df['IBE8641']))
# df['IBE9042'] = np.where(df['IBE9042'] >= 2010.285, 2010.285, np.where(df['IBE9042'] <= 2009.5249999999999, 2009.5249999999999, df['IBE9042']))
# df['IBE9509'] = np.where(df['IBE9509'] >= 3.5, 3.5, np.where(df['IBE9509'] <= -0.5, -0.5, df['IBE9509']))
# df['AP003448'] = np.where(df['AP003448'] >= 15.5, 15.5, np.where(df['AP003448'] <= -4.5, -4.5, df['AP003448']))
# df['IBE8850'] = np.where(df['IBE8850'] >= 2.375, 2.375, np.where(df['IBE8850'] <= 1.7750000000000001, 1.7750000000000001, df['IBE8850']))
# df['AP001242'] = np.where(df['AP001242'] >= 31.5, 31.5, np.where(df['AP001242'] <= -4.5, -4.5, df['AP001242']))
# df['IBE9511'] = np.where(df['IBE9511'] >= 1.48, 1.48, np.where(df['IBE9511'] <= 1.48, 1.48, df['IBE9511']))
# df['IBE8611_02'] = np.where(df['IBE8611_02'] >= 16.5, 16.5, np.where(df['IBE8611_02'] <= -3.5, -3.5, df['IBE8611_02']))
# df['IBE8602'] = np.where(df['IBE8602'] >= 2.55, 2.55, np.where(df['IBE8602'] <= -1.53, -1.53, df['IBE8602']))
# df['IBE9150_06'] = np.where(df['IBE9150_06'] >= 1.66, 1.66, np.where(df['IBE9150_06'] <= 1.66, 1.66, df['IBE9150_06']))
# df['IBE9150_03'] = np.where(df['IBE9150_03'] >= 1.48, 1.48, np.where(df['IBE9150_03'] <= 1.48, 1.48, df['IBE9150_03']))
# df['IBE8618_02'] = np.where(df['IBE8618_02'] >= 8.5, 8.5, np.where(df['IBE8618_02'] <= 4.5, 4.5, df['IBE8618_02']))
# df['AP002779'] = np.where(df['AP002779'] >= 3.5, 3.5, np.where(df['AP002779'] <= -0.5, -0.5, df['AP002779']))
# df['AP003589'] = np.where(df['AP003589'] >= 16.0, 16.0, np.where(df['AP003589'] <= 0.0, 0.0, df['AP003589']))
# df['AP001218'] = np.where(df['AP001218'] >= 6.0, 6.0, np.where(df['AP001218'] <= -2.0, -2.0, df['AP001218']))
# df['IBE8590_02'] = np.where(df['IBE8590_02'] >= 6.74, 6.74, np.where(df['IBE8590_02'] <= 6.74, 6.74, df['IBE8590_02']))
# df['IBE9514'] = np.where(df['IBE9514'] >= 3.5, 3.5, np.where(df['IBE9514'] <= -0.5, -0.5, df['IBE9514']))
# df['AP002780'] = np.where(df['AP002780'] >= 13.5, 13.5, np.where(df['AP002780'] <= -6.5, -6.5, df['AP002780']))
# df['IBE7650_01'] = np.where(df['IBE7650_01'] >= 6.0, 6.0, np.where(df['IBE7650_01'] <= -2.0, -2.0, df['IBE7650_01']))
# df['IBE7641_01'] = np.where(df['IBE7641_01'] >= 10.5, 10.5, np.where(df['IBE7641_01'] <= 6.5, 6.5, df['IBE7641_01']))
# df['IBE9641'] = np.where(df['IBE9641'] >= 10.5, 10.5, np.where(df['IBE9641'] <= 6.5, 6.5, df['IBE9641']))
# df['IBE8623_02'] = np.where(df['IBE8623_02'] >= 16.5, 16.5, np.where(df['IBE8623_02'] <= -3.5, -3.5, df['IBE8623_02']))
# df['IBE9150_07'] = np.where(df['IBE9150_07'] >= 3.27, 3.27, np.where(df['IBE9150_07'] <= 3.27, 3.27, df['IBE9150_07']))
# df['IBE8645'] = np.where(df['IBE8645'] >= 11.0, 11.0, np.where(df['IBE8645'] <= 3.0, 3.0, df['IBE8645']))
# df['IBE8647'] = np.where(df['IBE8647'] >= 2.2249999999999996, 2.2249999999999996, np.where(df['IBE8647'] <= 1.6250000000000002, 1.6250000000000002, df['IBE8647']))
# df['IBE9150_04'] = np.where(df['IBE9150_04'] >= 1.37, 1.37, np.where(df['IBE9150_04'] <= 1.37, 1.37, df['IBE9150_04']))
# df['IBE9150_05'] = np.where(df['IBE9150_05'] >= 2.165, 2.165, np.where(df['IBE9150_05'] <= 1.7249999999999996, 1.7249999999999996, df['IBE9150_05']))
# df['IBE9150_02'] = np.where(df['IBE9150_02'] >= 1.3, 1.3, np.where(df['IBE9150_02'] <= 1.3, 1.3, df['IBE9150_02']))
# df['IBE2526'] = np.where(df['IBE2526'] >= 3.5, 3.5, np.where(df['IBE2526'] <= -0.5, -0.5, df['IBE2526']))
# df['AP006246_01'] = np.where(df['AP006246_01'] >= 1.0, 1.0, np.where(df['AP006246_01'] <= 1.0, 1.0, df['AP006246_01']))
# df['IBE9510'] = np.where(df['IBE9510'] >= 2.2399999999999998, 2.2399999999999998, np.where(df['IBE9510'] <= 1.6, 1.6, df['IBE9510']))
# df['IBE8839_02'] = np.where(df['IBE8839_02'] >= 7.5, 7.5, np.where(df['IBE8839_02'] <= 3.5, 3.5, df['IBE8839_02']))

# %% [markdown]
# ## Show Transformed Dataframe

# %% [markdown]
# Gives the dataframe after all the transformations are done
#
# :return: datarame of the transformed data

# %%
excel_report.show_transformed_data()
# Out:
#        IBE8661_01    IBE8747                    IBE8594  IBE2361    IBE8707  \
# ID
# 189235    MICHAEL  230682.82       33  00139-0000-05410  4458.33  406647.95
# 201842    MICHAEL  230682.82             03-123-00-0153  4458.33  406647.95
# 9536      MICHAEL  230682.82  48  03301-0000-00032-  01  4458.33  406647.95
# 166586    MICHAEL  230682.82                   8.00E+17  4458.33  406647.95
# 137724    MICHAEL  230682.82             39-574-00-0052  4458.33  406647.95
# ...           ...        ...                        ...      ...        ...
# 53706     MICHAEL  230682.82        554201 97.20-1-25.2  4458.33  406647.95
# 34363     MICHAEL  230682.82                   19311015  4458.33  406647.95
# 49329     MICHAEL  230682.82       22  00046-  04-00031  4458.33  406647.95
# 249331    MICHAEL  230682.82                 01231-1101  4458.33  406647.95
# 124202    MICHAEL  230682.82             19-046-00-0020  4458.33  406647.95
#
#           IBE8706    IBE8702  IBE6867  IBE2762  IBE2195  ... IBE8505  \
# ID                                                       ...
# 189235  241518.97  534291.49   396.25   396.25  1342.73  ...       D
# 201842  241518.97  610472.34   396.25   396.25  1342.73  ...       D
# 9536    241518.97  625708.51   396.25   396.25  1342.73  ...       D
# 166586  241518.97  610472.34   396.25   396.25  1342.73  ...       D
# 137724  241518.97  534291.49   396.25   396.25  1342.73  ...       D
# ...           ...        ...      ...      ...      ...  ...     ...
# 53706   241518.97  610472.34   396.25   396.25  1342.73  ...       D
# 34363   241518.97  610472.34   396.25   396.25  1342.73  ...       D
# 49329   241518.97  534291.49   396.25   396.25  1342.73  ...       D
# 249331  241518.97  534291.49   396.25   396.25  1342.73  ...       D
# 124202  241518.97  610472.34   396.25   396.25  1342.73  ...       D
#
#         IBE7601_16  IBE8839_02  IBE9510  IBE7629_02  PX001274_02  PX001270_02  \
# ID
# 189235           4        6.50     1.60           3            3            3
# 201842           4        3.50     1.84           3            3            3
# 9536             3        5.00     1.60           3            3            3
# 166586           4        5.67     1.84           3            3            3
# 137724           4        5.67     1.60           3            3            3
# ...            ...         ...      ...         ...          ...          ...
# 53706            4        5.67     2.00           3            3            3
# 34363            4        5.00     1.84           3            3            3
# 49329            4        6.00     1.84           3            3            3
# 249331           4        6.50     1.84           3            3            3
# 124202           4        3.50     2.00           3            3            3
#
#         PX001271_02  IBE8701  Target
# ID
# 189235            3        R       0
# 201842            3        R       0
# 9536              3        R       0
# 166586            3        R       0
# 137724            3        R       0
# ...             ...      ...     ...
# 53706             3        R       0
# 34363             3        R       0
# 49329             3        R       0
# 249331            3        R       0
# 124202            3        R       0
#
# [56657 rows x 427 columns]
